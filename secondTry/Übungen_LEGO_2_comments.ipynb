# %% [markdown]
# # Übungssession zu Pandas
#
# Erinnerung: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import numpy as np
import pandas as pd

# %%
LEGO_all = pd.read_csv("LEGO.csv")
LEGO = LEGO_all[LEGO_all["date"] == LEGO_all["date"].max()].copy()
LEGO.head(3)
# Out:
#             name         theme  product_code ageRange  pieceCount   price  \
# 0    Burg Himeji  Architecture         21060      18+      2125.0  159.99
# 1  New York City  Architecture         21028      12+       598.0   49.99
# 2      Taj Mahal  Architecture         21056      18+      2022.0  119.99
#
#    minifigureCount buildHeight buildWidth buildDepth  \
# 0              NaN         NaN        NaN        NaN
# 1              NaN         NaN        NaN        NaN
# 2              NaN        20.0       23.0       23.0
#
#                                   url        date
# 0  /de-de/product/himeji-castle-21060  2023-09-21
# 1  /de-de/product/new-york-city-21028  2023-09-21
# 2      /de-de/product/taj-mahal-21056  2023-09-21

# %% [markdown]
# ### Frage 1: Preispolitik
#
# Wie oft kommen (bei den aktuellen Modellen) die unterschiedlichen Preise jeweils vor? Sortieren Sie die Preise nach ihrer Häufigkeit.
#
# Ergänzen Sie ferner Ihre Tabelle um eine Spalte in der nicht die absolute sondern die relative Häufigkeit (d.h. der prozentuale Anteil) steht.

# %% [markdown]
# ### Einschub
#
# Bisher hatten wir Split-Apply-Combine in einer relativ einfachen Form gesehen.
# Meist wurde nach der Gruppierung eine explizite Spalte ausgewählt und darauf eine Aggregationsfunktion angewandt.
# Grundsätzlich kann man auch beliebige Funktionen auf die jeweiligen SubDataFrames anwenden.

# %%
def my_function(subdf):
    rows = len(subdf)
    unique_prices= subdf["price"].nunique() # n unique anzahl der Eigenartigen
    return pd.Series([rows, unique_prices], index = ["num_rows","unique_prices" ])

LEGO.groupby("theme").apply(my_function)
# Out:
#                            num_rows  unique_prices
# theme
# Architecture                      9              7
# Art                               6              6
# Batman™                          10              7
# BrickHeadz                       24              5
# City                             91             25
# Classic                          27             14
# Creator 3-in-1-Sets              28             14
# Creator Expert                    7              6
# DC                                5              5
# DOTS                             24             12
# DUPLO®                           55             19
# Die Eiskönigin                    3              2
# Disney Mickey and Friends         1              1
# Disney™                          62             23
# Friends                          59             20
# Harry Potter™                    73             32
# Ideas                            18             11
# Jurassic World™                  20             14
# LEGO® Avatar                      9              7
# LEGO® DREAMZzz™                  13             12
# LEGO® Education                  13             12
# LEGO® Gabbys Puppenhaus           4              4
# LEGO® Icons                      36             17
# LEGO® Indiana Jones™              3              3
# LEGO® Originals                   1              1
# LEGO® Sonic the Hedgehog™         9              8
# LEGO® Super Mario™               29             19
# Lord of the Rings™                1              1
# MINDSTORMS®                       1              1
# Marvel                           45             26
# Minecraft®                       30             15
# Minifiguren                      56             20
# Monkie Kid™                      17             12
# NINJAGO®                         65             26
# Powered UP                       11              8
# SERIOUS PLAY®                     4              4
# Sonstiges                         1              1
# Speed Champions                  14              2
# Spider-Man                       17             11
# Star Wars™                      108             39
# Technic                          44             24
# Xtra                              1              1

# %% [markdown]
# ### Frage 2: Teure Modelle
#
# Die Tabelle (nur die aktuellen Modelle) soll so eingeschränkt werden, dass für jedes Thema nur die drei teuersten Modelle enthalten sind.

# %%
def other_function(subdf):
    return subdf.sort_values("price", ascending = False).head(3)

LEGO.groupby("theme").apply(other_function).reset_index(drop = True)
# Out:
#                                                   name         theme  \
# 0                                          Burg Himeji  Architecture
# 1                                      Cheops-Pyramide  Architecture
# 2                                            Taj Mahal  Architecture
# 3                                            Weltkarte           Art
# 4                                   The Rolling Stones           Art
# ..                                                 ...           ...
# 109  Republikanischer Angriffskreuzer der Venator-K...    Star Wars™
# 110                       Liebherr LR 13000 Raupenkran       Technic
# 111                  Appgesteuerter Cat® D11 Bulldozer       Technic
# 112                            Lamborghini Sián FKP 37       Technic
# 113                                       Sportzubehör          Xtra
#
#      product_code ageRange  pieceCount   price  minifigureCount buildHeight  \
# 0           21060      18+      2125.0  159.99              NaN         NaN
# 1           21058      18+      1476.0  139.99              NaN         NaN
# 2           21056      18+      2022.0  119.99              NaN        20.0
# 3           31203      18+     11695.0  249.99              NaN        65.0
# 4           31206      18+      1998.0  149.99              NaN         NaN
# ..            ...      ...         ...     ...              ...         ...
# 109         75367      18+      5374.0  649.99              2.0        32.0
# 110         42146      18+      2883.0  679.99              NaN         NaN
# 111         42131      18+      3854.0  499.99              NaN        26.0
# 112         42115      18+      3696.0  449.99              NaN         NaN
# 113         40375       6+        36.0    3.99              NaN         NaN
#
#     buildWidth buildDepth                                                url  \
# 0          NaN        NaN                 /de-de/product/himeji-castle-21060
# 1          NaN        NaN         /de-de/product/great-pyramid-of-giza-21058
# 2         23.0       23.0                     /de-de/product/taj-mahal-21056
# 3        104.0        NaN                     /de-de/product/world-map-31203
# 4          NaN        NaN            /de-de/product/the-rolling-stones-31206
# ..         ...        ...                                                ...
# 109       54.0      109.0               /de-de/product/tdb-lsw-2023-24-75367
# 110        NaN        NaN  /de-de/product/liebherr-crawler-crane-lr-13000...
# 111       57.0       37.0  /de-de/product/app-controlled-cat-d11-bulldoze...
# 112        NaN        NaN       /de-de/product/lamborghini-sian-fkp-37-42115
# 113        NaN        NaN            /de-de/product/sports-accessories-40375
#
#            date
# 0    2023-09-21
# 1    2023-09-21
# 2    2023-09-21
# 3    2023-09-21
# 4    2023-09-21
# ..          ...
# 109  2023-09-21
# 110  2023-09-21
# 111  2023-09-21
# 112  2023-09-21
# 113  2023-09-21
#
# [114 rows x 12 columns]

# %% [markdown]
# ### Einschub
#
# Mit filter() kann man ganze Gruppen entfernen, sofern sie ein Kriterium nicht erfüllen.
#
# Bsp: Behalte nur diejenigen Themengruppen, welche maximal zwei Sets enthalten.

# %%
def func_3(subdf):

    return len(subdf) <= 3
LEGO.groupby("theme").filter(func_3)
# Out:
#                                                    name  \
# 161   The LEGO Ideas Book New Edition: You Can Build...
# 227                              Kleines Disney Schloss
# 275                               Elsas Schmuckkästchen
# 589                        DER HERR DER RINGE: BRUCHTAL
# 603                          Tempel des goldenen Götzen
# 604                              Flucht aus dem Grabmal
# 605                         Flucht vor dem Jagdflugzeug
# 700                                    Roboter-Erfinder
# 732                                      Holz-Minifigur
# 1043                                       Sportzubehör
# 1049  LEGO® l Disney Die Eiskönigin 2 Anna-Schlüssel...
# 1050  LEGO® l Disney Die Eiskönigin 2 Elsa-Schlüssel...
#
#                           theme  product_code ageRange  pieceCount   price  \
# 161                   Sonstiges       5007583       7+         0.0   24.99
# 227   Disney Mickey and Friends         40478      12+       567.0   39.99
# 275              Die Eiskönigin         41168       6+       300.0   39.99
# 589          Lord of the Rings™         10316      18+      6167.0  499.99
# 603        LEGO® Indiana Jones™         77015      18+      1545.0  149.99
# 604        LEGO® Indiana Jones™         77013       8+       600.0   39.99
# 605        LEGO® Indiana Jones™         77012       8+       387.0   34.99
# 700                 MINDSTORMS®         51515      10+       949.0  359.99
# 732             LEGO® Originals       5007523       6+         0.0  119.99
# 1043                       Xtra         40375       6+        36.0    3.99
# 1049             Die Eiskönigin        853969       6+         0.0    5.99
# 1050             Die Eiskönigin        853968       6+         0.0    5.99
#
#       minifigureCount buildHeight buildWidth buildDepth  \
# 161               NaN         NaN        NaN        NaN
# 227               NaN         NaN        NaN        NaN
# 275               NaN         NaN        NaN        NaN
# 589              15.0        39.0       72.0       50.0
# 603               NaN         NaN        NaN        NaN
# 604               NaN         NaN        NaN        NaN
# 605               NaN         NaN        NaN        NaN
# 700               NaN         NaN        NaN        NaN
# 732               NaN         NaN        NaN        NaN
# 1043              NaN         NaN        NaN        NaN
# 1049              NaN         NaN        NaN        NaN
# 1050              NaN         NaN        NaN        NaN
#
#                                                     url        date
# 161   /de-de/product/the-lego-ideas-book-new-edition...  2023-09-21
# 227             /de-de/product/mini-disney-castle-40478  2023-09-21
# 275    /de-de/product/elsa-s-jewelry-box-creation-41168  2023-09-21
# 589                           /de-de/product/lotr-10316  2023-09-21
# 603      /de-de/product/temple-of-the-golden-idol-77015  2023-09-21
# 604      /de-de/product/escape-from-the-lost-tomb-77013  2023-09-21
# 605            /de-de/product/fighter-plane-chase-77012  2023-09-21
# 700                 /de-de/product/robot-inventor-51515  2023-09-21
# 732            /de-de/product/wooden-minifigure-5007523  2023-09-21
# 1043            /de-de/product/sports-accessories-40375  2023-09-21
# 1049  /de-de/product/lego--disney-frozen-2-anna-key-...  2023-09-21
# 1050  /de-de/product/lego--disney-frozen-2-elsa-key-...  2023-09-21

# %% [markdown]
# Mit transform() kann man eine Funktion aufrufen aber den Index der ursprünglichen Spalte (d.h. vor der Gruppierung) belassen.
# Dies ist meist hilfreich wenn man einen aggregierten Wert über alle Zeilen verteilen möchte, von denen er stammt.

# %% [markdown]
# ### Frage 3: Neue Modelle
#
# Welche Modelle sind im aktuellen Halbjahr neu hinzugekommen?

# %%
#LEGO_all[LEGO_all["date"] == "2023-09-21"]

## Fabian Lösung
LEGO_all = LEGO_all.sort_values(["product_code", "date"])
LEGO_all.head()
# Out:
#                  name    theme  product_code ageRange  pieceCount  price  \
# 3911  Elementetrenner  Classic           630       4+         1.0   2.49
# 3161  Elementetrenner  Classic           630       4+         1.0   2.49
# 2187  Elementetrenner  Classic           630       4+         1.0   2.49
# 1226  Elementetrenner  Classic           630       4+         1.0   2.49
# 172   Elementetrenner  Classic           630       4+         1.0   2.49
#
#       minifigureCount buildHeight buildWidth buildDepth  \
# 3911              NaN         NaN        NaN        NaN
# 3161              NaN         NaN        NaN        NaN
# 2187              NaN         NaN        NaN        NaN
# 1226              NaN         NaN        NaN        NaN
# 172               NaN         NaN        NaN        NaN
#
#                                      url        date
# 3911  /de-de/product/brick-separator-630  2021-10-04
# 3161  /de-de/product/brick-separator-630  2022-03-22
# 2187  /de-de/product/brick-separator-630  2022-09-19
# 1226  /de-de/product/brick-separator-630  2023-02-28
# 172   /de-de/product/brick-separator-630  2023-09-21

# %%
counts = LEGO_all.groupby("product_code").size().reset_index(name = "anzahl")
counts.head()
# Out:
#    product_code  anzahl
# 0           630       5
# 1          2304       1
# 2         10255       5
# 3         10258       1
# 4         10261       1

# %%
df = pd.merge(LEGO_all, counts, how="left", left_on = "product_code", right_on= "product_code")
df.head(7)
# Out:
#                            name           theme  product_code ageRange  \
# 0               Elementetrenner         Classic           630       4+
# 1               Elementetrenner         Classic           630       4+
# 2               Elementetrenner         Classic           630       4+
# 3               Elementetrenner         Classic           630       4+
# 4               Elementetrenner         Classic           630       4+
# 5  Grüne LEGO® DUPLO® Bauplatte          DUPLO®          2304      NaN
# 6                    Stadtleben  Creator Expert         10255      16+
#
#    pieceCount   price  minifigureCount buildHeight buildWidth buildDepth  \
# 0         1.0    2.49              NaN         NaN        NaN        NaN
# 1         1.0    2.49              NaN         NaN        NaN        NaN
# 2         1.0    2.49              NaN         NaN        NaN        NaN
# 3         1.0    2.49              NaN         NaN        NaN        NaN
# 4         1.0    2.49              NaN         NaN        NaN        NaN
# 5         1.0   14.99              NaN         NaN        NaN        NaN
# 6      4002.0  239.99              NaN         NaN        NaN        NaN
#
#                                                  url        date  anzahl
# 0                 /de-de/product/brick-separator-630  2021-10-04       5
# 1                 /de-de/product/brick-separator-630  2022-03-22       5
# 2                 /de-de/product/brick-separator-630  2022-09-19       5
# 3                 /de-de/product/brick-separator-630  2023-02-28       5
# 4                 /de-de/product/brick-separator-630  2023-09-21       5
# 5  /de-de/product/lego-duplo-large-green-building...  2021-10-04       1
# 6               /de-de/product/assembly-square-10255  2021-10-04       5

# %%
df[(df["anzahl"]== 1 )& (df["data"] == df["date"].max())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/emreo/PythonDataScience/secondTry/Übungen_LEGO_2_comments.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/home/emreo/PythonDataScience/secondTry/%C3%9Cbungen_LEGO_2_comments.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df[(df["anzahl"]== 1 )& (df["data"] == df["date"].max())]
#
# File ~/.conda/envs/myenv/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/.conda/envs/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'data'
